# %% [markdown]
# #### Import Libraries

# %%
#import libraries
import numpy as np
import pandas as pd

# %% [markdown]
# #### Load the dataset

# %%
df = pd.read_csv("dataset/Activity_Dataset_V1.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0 activity_day     workout_type  distance  time  calories  \
# 0           0   2022-01-01        Freestyle      9.30    77       123
# 1           1   2022-01-01        Freestyle      3.44    96        55
# 2           2   2022-01-01   Indoor Cycling      6.34    85        33
# 3           3   2022-01-01          Walking      7.91    42        82
# 4           4   2022-01-01       Open Water      8.99    36       131
# 5           5   2022-01-01  Outdoor Cycling      5.47   117       144
# 6           6   2022-01-01   Indoor Cycling      6.28    66       378
# 7           7   2022-01-01  Outdoor Running      2.94    26       430
# 8           8   2022-01-01        Trail Run      2.87    26       465
# 9           9   2022-01-01    Pool Swimming      3.91    23        99
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1000 non-null   int64
#  1   activity_day    1000 non-null   object
#  2   workout_type    1000 non-null   object
#  3   distance        1000 non-null   float64
#  4   time            1000 non-null   int64
#  5   calories        1000 non-null   int64
#  6   total_steps     554 non-null    float64
#  7   avg_speed       1000 non-null   float64
#  8   avg_cadence     1000 non-null   float64
#  9   max_cadence     1000 non-null   float64
#  10  avg_pace        554 non-null    object
#  11  max_pace        554 non-null    object
#  12  min_pace        554 non-null    object
#  13  avg_heart_rate  1000 non-null   float64
#  14  max_heart_rate  1000 non-null   float64
#  15  min_heart_rate  1000 non-null   int64
#  16  vo2_max(%)      1000 non-null   int64
# ...

# %%
df.iloc[:,df.columns.isin(['distance','time','calories','total_steps', 'avg_heart_rate'])].describe()
# Out:
#           distance         time     calories  total_steps  avg_heart_rate
# count  1000.000000  1000.000000  1000.000000   554.000000     1000.000000
# mean      5.243620    71.166000   286.310000  4081.119134      116.282000
# std       2.649774    29.341359   156.278511  1865.429141       20.573679
# min       1.000000    20.000000    10.000000  1571.000000       82.500000
# 25%       2.800000    45.000000   155.750000  2790.000000       97.000000
# 50%       5.105000    71.000000   290.500000  3444.000000      113.000000
# 75%       7.542500    97.000000   415.250000  5028.000000      136.500000
# max       9.990000   120.000000   550.000000  7618.000000      150.500000
